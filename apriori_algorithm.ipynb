# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
dataset=pd.read_csv('/Users/sai/Projects/mlprojects/groceries - groceries.csv')

# %%
dataset.describe()
# Out:
#            Item(s)
# count  9835.000000
# mean      4.409456
# std       3.589385
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       6.000000
# max      32.000000

# %%
dataset.head(100)
# Out:
#     Item(s)            Item 1               Item 2          Item 3  \
# 0         4      citrus fruit  semi-finished bread       margarine
# 1         3    tropical fruit               yogurt          coffee
# 2         1        whole milk                  NaN             NaN
# 3         4         pip fruit               yogurt    cream cheese
# 4         4  other vegetables           whole milk  condensed milk
# ..      ...               ...                  ...             ...
# 95        2            grapes           photo/film             NaN
# 96        9           sausage        sliced cheese      rolls/buns
# 97       10           chicken       hamburger meat    citrus fruit
# 98        3        whole milk               yogurt     brown bread
# 99        2      citrus fruit       tropical fruit             NaN
#
#                       Item 4                 Item 5            Item 6  \
# 0                ready soups                    NaN               NaN
# ...

# %%
if 'Item(s)' in dataset.columns:
    dataset = dataset.drop(columns=['Item(s)'])

# %%
dataset.head()
# Out:
#              Item 1               Item 2          Item 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9 Item 10  ...  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 1                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 2                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN     NaN  ...
#
#   Item 23 Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30 Item 31  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
import re

def is_not_number(item):
    
    return not re.fullmatch(r'\d+', str(item).strip())


filtered_transactions = [[item for item in transaction if is_not_number(item)] for transaction in cleaned_transactions]


te = TransactionEncoder()
te_ary = te.fit(filtered_transactions).transform(filtered_transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)


frequent_itemsets = apriori(df, min_support=0.02, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

print(frequent_itemsets.head())
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head())
# Out:
#     support        itemsets
# 0  0.033449      (UHT-milk)
# 1  0.052460          (beef)
# 2  0.033245       (berries)
# 3  0.026027     (beverages)
# 4  0.080521  (bottled beer)
#           antecedents         consequents   support  confidence      lift
# 0              (beef)        (whole milk)  0.021248    0.405039  1.585341
# 1        (whole milk)              (beef)  0.021248    0.083168  1.585341
# 2     (bottled water)  (other vegetables)  0.024807    0.224471  1.160219
# 3  (other vegetables)     (bottled water)  0.024807    0.128219  1.160219
# 4     (bottled water)        (rolls/buns)  0.024197    0.218951  1.190494
