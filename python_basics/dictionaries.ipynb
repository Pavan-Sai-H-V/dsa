# %%
trip={
    'agent':'Pavan',
    "car":"Lambo",
    'time':'10.00am',
    'Tools':'M416',
    'places':['Adyar','Velachery','Medavakkam','Porur','SIPCOT']
}

# %%
print(type(trip))
# Out:
# <class 'dict'>

# %%
trip.keys()
# Out:
# dict_keys(['agent', 'car', 'time', 'Tools'])

# %%
trip.values()
# Out:
# dict_values(['Pavan', 'Lambo', '10.00am', 'M416'])

# %%
for key,values in trip.items():
    print (key,":",values)
# Out:
# agent : Pavan
# car : Lambo
# time : 10.00am
# Tools : M416
# age : 23

# %%
trip.update({'age':'23'})

# %%
print(trip['places'][1])
# Out:
# Velachery

# %%
for l in trip["places"]:
    print(l)
# Out:
# Adyar
# Velachery
# Medavakkam
# Porur
# SIPCOT

# %%
trips=[
    {'trip_id':'1','pickup':'adyar','drop':'Airport','fare':950},
    {'trip_id':'2','pickup':'Padur','drop':'Airport','fare':1150},
    {'trip_id':'3','pickup':'Velachery','drop':'Airport','fare':750},
]

# %%
trips=[
    {'trip_id':'1','pickup':'adyar','drop':'Airport','fare':950},
    {'trip_id':'2','pickup':'Padur','drop':'Airport','fare':1150},
    {'trip_id':'3','pickup':'Velachery','drop':'Airport','fare':750},
]

# %%
for t in trips:
    print(t["trip_id"])
# Out:
# 1
# 2
# 3

# %%
trips={
    'id1':{'trip_id':'1','pickup':'adyar','drop':'Airport','fare':950},
    'id2':{'trip_id':'2','pickup':'Padur','drop':'Airport','fare':1150},
    'id3':{'trip_id':'3','pickup':'Velachery','drop':'Airport','fare':750},
}

# %%
for k,v in trips.items():
    print(k)
    print(v['pickup'],"->",v['drop'])
# Out:
# id1
# adyar -> Airport
# id2
# Padur -> Airport
# id3
# Velachery -> Airport
