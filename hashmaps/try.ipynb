# %% [markdown]
# Valid Sudokuu

# %%
from collections import defaultdict

# %%
List=[["5","3",".",".","7",".",".",".","."]
,["6",".",".","1","9","5",".",".","."]
,[".","9","8",".",".",".",".","6","."]
,["8",".",".",".","6",".",".",".","3"]
,["4",".",".","8",".","3",".",".","1"]
,["7",".",".",".","2",".",".",".","6"]
,[".","6",".",".",".",".","2","8","."]
,[".",".",".","4","1","9",".",".","5"]
,[".",".",".",".","8",".",".","7","9"]]
def isValidSudoku(board):
        rows = defaultdict(set)
        cols = defaultdict(set)
        boxes = defaultdict(set)
        
        for r in range(9):
            for c in range(9):
                if board[r][c] == ".":
                    continue
                
                if board[r][c] in rows[r] or board[r][c] in cols[c] or board[r][c] in boxes[(r // 3, c // 3)]:
                    return False
                
                rows[r].add(board[r][c])
                print(rows)
                cols[c].add(board[r][c])
                print(cols)
                boxes[(r // 3, c // 3)].add(board[r][c])
                print(boxes)
        
        return True
        
isValidSudoku(List)
# Out:
# defaultdict(<class 'set'>, {0: {'5'}})
# defaultdict(<class 'set'>, {0: {'5'}})
# defaultdict(<class 'set'>, {(0, 0): {'5'}})
# defaultdict(<class 'set'>, {0: {'3', '5'}})
# defaultdict(<class 'set'>, {0: {'5'}, 1: {'3'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}})
# defaultdict(<class 'set'>, {0: {'5'}, 1: {'3'}, 4: {'7'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5'}, (0, 1): {'7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'6'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3'}, 4: {'7'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5', '6'}, (0, 1): {'7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '6'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3'}, 4: {'7'}, 3: {'1'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5', '6'}, (0, 1): {'1', '7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '6'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3'}, 4: {'9', '7'}, 3: {'1'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5', '6'}, (0, 1): {'1', '9', '7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3'}, 4: {'9', '7'}, 3: {'1'}, 5: {'5'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '5', '6'}, (0, 1): {'1', '9', '5', '7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'9'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3', '9'}, 4: {'9', '7'}, 3: {'1'}, 5: {'5'}})
# defaultdict(<class 'set'>, {(0, 0): {'3', '9', '5', '6'}, (0, 1): {'1', '9', '5', '7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3', '9'}, 4: {'9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}})
# defaultdict(<class 'set'>, {0: {'5', '6'}, 1: {'3', '9'}, 4: {'9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8'}})
# defaultdict(<class 'set'>, {0: {'8', '5', '6'}, 1: {'3', '9'}, 4: {'9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '6'}})
# defaultdict(<class 'set'>, {0: {'8', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8'}, (1, 1): {'6'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}})
# defaultdict(<class 'set'>, {0: {'8', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}, 8: {'3'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8'}, (1, 1): {'6'}, (1, 2): {'3'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'4'}})
# defaultdict(<class 'set'>, {0: {'8', '4', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}, 8: {'3'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4'}, (1, 1): {'6'}, (1, 2): {'3'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '4'}})
# defaultdict(<class 'set'>, {0: {'8', '4', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'8', '1'}, 5: {'5'}, 2: {'8'}, 7: {'6'}, 8: {'3'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4'}, (1, 1): {'8', '6'}, (1, 2): {'3'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4'}})
# defaultdict(<class 'set'>, {0: {'8', '4', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'3'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4'}, (1, 1): {'8', '3', '6'}, (1, 2): {'3'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'8', '4', '5', '6'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'3', '1'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4'}, (1, 1): {'8', '3', '6'}, (1, 2): {'3', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'7'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9'}, 4: {'6', '9', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'3', '1'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '6'}, (1, 2): {'3', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'2', '7'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9'}, 4: {'6', '9', '2', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'3', '1'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'3', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9'}, 4: {'6', '9', '2', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'6', '3', '1'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'6'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'6', '9', '2', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'6', '3', '1'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'2', '6'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'6', '9', '2', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'6'}, 8: {'6', '3', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'2'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'6', '9', '2', '7'}, 3: {'8', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'4'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'6', '9', '2', '7'}, 3: {'8', '4', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2'}, (2, 1): {'4'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'4', '1'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2'}, (2, 1): {'4', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'9', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '9', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2'}, (2, 1): {'9', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'9', '5', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '9', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '5', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2', '5'}, (2, 1): {'9', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'9', '5', '4', '1'}, 8: {'8'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'8', '9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '9', '5'}, 2: {'8'}, 7: {'8', '6'}, 8: {'6', '3', '5', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2', '5'}, (2, 1): {'8', '9', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'9', '5', '4', '1'}, 8: {'8', '7'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'8', '9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '9', '5'}, 2: {'8'}, 7: {'8', '7', '6'}, 8: {'6', '3', '5', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '2', '5', '7'}, (2, 1): {'8', '9', '4', '1'}})
# defaultdict(<class 'set'>, {0: {'3', '5', '7'}, 1: {'1', '9', '5', '6'}, 2: {'8', '9', '6'}, 3: {'8', '3', '6'}, 4: {'8', '3', '4', '1'}, 5: {'6', '2', '7'}, 6: {'8', '2', '6'}, 7: {'9', '5', '4', '1'}, 8: {'8', '9', '7'}})
# defaultdict(<class 'set'>, {0: {'8', '6', '5', '4', '7'}, 1: {'3', '9', '6'}, 4: {'8', '9', '2', '6', '1', '7'}, 3: {'8', '4', '1'}, 5: {'3', '9', '5'}, 2: {'8'}, 7: {'8', '7', '6'}, 8: {'3', '9', '6', '5', '1'}, 6: {'2'}})
# defaultdict(<class 'set'>, {(0, 0): {'8', '3', '9', '6', '5'}, (0, 1): {'1', '9', '5', '7'}, (0, 2): {'6'}, (1, 0): {'8', '4', '7'}, (1, 1): {'8', '3', '2', '6'}, (1, 2): {'6', '3', '1'}, (2, 0): {'6'}, (2, 2): {'8', '9', '2', '5', '7'}, (2, 1): {'8', '9', '4', '1'}})
# True

# %%
List1=[["5","3",".",".","7",".",".",".","."]
,["6",".",".","1","9","5",".",".","."]
,[".","9","8",".",".",".",".","6","."]
,["8",".",".",".","6",".",".",".","3"]
,["4",".",".","8",".","3",".",".","1"]
,["7",".",".",".","2",".",".",".","6"]
,[".","6",".",".",".",".","2","8","."]
,[".",".",".","4","1","9",".",".","5"]
,[".",".",".",".","8",".",".","7","9"]]

r=defaultdict(set)
c=defaultdict(set)

# %%
hashmap=defaultdict(set)
type(hashmap)

list=[[1,2],[2,1],[3,4]]

for r in range(3):
    for c in range(2):
        hashmap[r].add(list[r][c])
        hashmap[c].add(list[r][c])

hashmap
# Out:
# defaultdict(set, {0: {1, 2, 3}, 1: {1, 2, 4}, 2: {3, 4}})

# %% [markdown]
# find out the len of unmacthed char in string

# %%
a='Pavan'
b='Pawccan'
c=0

    
def clac(a, b):
    a = set(a)
    b = set(b)
    unmatched = (a - b) | (b - a)
    return len(unmatched)

clac(a, b)
# Out:
# 3

# %%
s1='Sarath Kumar'
s2='Rahul Gandhi'
for i in s1:
    if i in s2:
        s1=s1.replace(i,'',1)
        s2=s2.replace(i,'',1)
print(len(s1+s2))
# Out:
# 14

# %%
a='hello how are you'
b=a[::-1]
b
# Out:
# 'uoy era woh olleh'

# %%
a='hello how are you'
d=[]
for i in a:
    d.append(i)
d

def rev(d):
    ra=len(d)-1
    for i in range(len(d)//2):
        d[i], d[ra] = d[ra], d[i]
        ra-=1
    return d

rev(d)
# Out:
# ['u',
#  'o',
#  'y',
#  ' ',
#  'e',
#  'r',
#  'a',
#  ' ',
#  'w',
#  'o',
#  'h',
#  ' ',
#  'o',
#  'l',
#  'l',
#  'e',
#  'h']

# %%
s="Hello How are you"
ans=''

i,j=0,len(s)-1
while (j>=0):
    if s[i]!=''and s[j]!='':
        ans+=s[j]
    elif s[j]!='':
        ans+=s[j]
    if s[i]=='':
        ans+=s[i]
    i+=1
    j-=1

print(ans)
# Out:
# uoy era woH olleH

# %%
ans=''
while (j>=0):
    if s[i]!='':
        ans+=s[j]
    elif s[i]=='':
        ans+=s[j]
    else:

# %%
ans=''
c,v=0,0
for i in range(len(s)-1):
    if a[v]!='':
        v+=1
    while a[v]=='':
        for d in range(v):

# %%
a='hello how are you'
b=a.split(' ')
b
# Out:
# ['hello', 'how', 'are', 'you']

# %%
c=''.join(i[::-1]+" " for i in b)
print(c)
# Out:
# olleh woh era uoy

# %%
a1="Hel1lo Ho#w are you?"
b1=a1.split('1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 a1="Hel1lo Ho#w are you?"
# ----> 2 b1=a1.split(['1','#','?'])
#
# TypeError: must be str or None, not list
