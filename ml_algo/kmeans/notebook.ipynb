# %%
from sklearn.datasets import make_blobs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=make_blobs()

# %%
dataset
# Out:
# (array([[-1.78766943, -6.38984587],
#         [-1.32535569,  8.3527722 ],
#         [-2.35250718, -5.00045863],
#         [ 4.49753054,  1.0634573 ],
#         [ 6.10659418,  1.35433961],
#         [ 6.17970435,  1.51526046],
#         [-0.16281947,  8.16382226],
#         [ 0.85322733,  7.41509374],
#         [ 0.50718384,  6.65203666],
#         [ 0.4439946 ,  9.25930195],
#         [-1.8107471 , -5.40424464],
#         [-3.12930057, -4.21529622],
#         [ 0.52106293,  6.46890074],
#         [ 4.00932609,  2.04922475],
#         [-1.64000335, -4.13531137],
#         [ 0.6174312 ,  8.65972594],
#         [ 0.52449921,  8.04983678],
#         [ 3.22508288,  1.88571603],
#         [-3.6665647 , -5.0066764 ],
#         [-3.12463469, -5.52116434],
#         [ 0.37508618,  7.40074538],
#         [-3.36884392, -3.91932445],
#         [ 4.10263378,  0.13383722],
#         [ 0.3030103 ,  6.58277875],
#         [ 1.38912528,  9.18583479],
#         [ 4.21710655,  1.67326357],
# ...
